# %%
import numpy as np
import control.matlab as mat
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
A = "0 1; 0.4 0.02"
B = "0; 1"
C = "1 0; 0 0"
D = "0 ;0"

sys1 = mat.ss(A,B,C,D)

# %%
T = np.arange(0,10,0.001)
yout, T = mat.step(sys1, T)

# %%
plt.plot(yout)

# %%
sys = mat.ss("1. -2; 3. -4", "5.; 7", "6. 8", "9.")
mag, phase, omega = mat.bode(sys)

# %%
sys = mat.ss("1. -2; 3. -4", "5.; 7", "6. 8", "9.")
omega = mat.default_frequency_range(sys)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-e77ab0e1ff07> in <module>
#       1 sys = mat.ss("1. -2; 3. -4", "5.; 7", "6. 8", "9.")
# ----> 2 omega = mat.default_frequency_range(sys)
#
# AttributeError: module 'control.matlab' has no attribute 'default_frequency_range'
