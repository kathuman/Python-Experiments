# %%
import random, math, itertools
import simpy
import numpy as np

class parameters:
    # Class that defines the parameters (p) of the simulation
    target_inventory = 200 # units
    reorder_point = 50 # units
    leadtime = 2 # days
    simulationTimeMax = 50 # days

class simulation:
    '''
    This class, the Simulation, is the one that contains all other agents. It is responsible for
        a.- advancing time
        b.- generating the interarrivel times for customers
        c.- generating the demands for each customer
    '''
    def __init__(self, env):
        self.clock = 0
        self.env = env
    # Class that defines a simulation (S)
    inv = None
    # Number of customers
    nCustomers = 0
    # Initialize the Customers per day array
    Cust_day = list(itertools.repeat(0, p.simulationTimeMax))
    
    def advance_time(self):
        t_event = min(self.t_customer, self.t_delivery)
        # self.cost_holding += self.inventory*HOLDING_COST*(t_event-self.clock)
        self.clock = t_event # advance clockto the next event
        if self.t_delivery <= self.t_customer:
            self.handle_delivery_event()
        else:
            self.handle_customer_event()
            
    def generate_interarrival(self):
        return np.random.exponential(1./5.0)
    
    def generate_demand(self):
        # return np.random.randint(1, 5)
        return int(np.random.normal(4,2))
        
    self.demand = 0
    self.t_customer = self.generate_interarrival()
    self.t_delivery = float('inf') # Initially delivery time is extrememly hig
    self.inventory = simpy.Container(env, init = p.target_inventory)
        self.monitoring = env.process(self.monitor_inv(env))
        self.inv_dataset = []
        self.demand_dataset = []
        if(name == ''):
            self.name = 'RandomWarehouse' + str(np.random.randint(100))
        else:
            self.name = name
    

    
    def monitor_inv(self, env):
        while True:
            self.inv_dataset.append(self.inventory.level)
            self.demand_dataset.append(self.demand)
            if self.inventory.level <= p.reorder_point:
                self.handle_delivery_event()
            yield self.env.timeout(1)
            
    def handle_delivery_event(self):
        print('Time {:.2f}: Inventory reached ROP: Warehouse {} requests replenishment order of {}'.format(self.env.now, self.name, P.target_inventory - self.inventory.level))
        yield self.env.timeout(p.leadtime)
        print('Time {:.2f}: Warehouse {} receives replenishment order of {}'.format(self.env.now, self.name, P.target_inventory - self.inventory.level))
        yield self.inventory.put(p.target_inventory - self.inventory.level)
            
    def handle_customer_event(self):
        demand = self.generate_demand()
        self.demand = demand
        if self.inventory.level > demand :
            # self.revenue += REVENUE_PER_ITEM*demand
            self.inventory.get(demand)
        else:
            # self.revenue += 100*self.inventory
            self.inventory.get(self.inventory.level)

# %%
np.random.seed(0)

envr = simpy.Environment()
s.wh = warehouse(envr, name = 'WH1')
envr.run(until = p.simulationTimeMax)

# %%
s.wh.inv_dataset
# Out:
# [200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200]
