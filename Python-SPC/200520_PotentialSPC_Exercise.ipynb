# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
# Guide: https://realpython.com/python-matplotlib-guide/

def pControlLimits(p, n, s=3):
    '''pControlLimits calulates the control limits of a sample with
    an average proportion of deficient elements p, and a sample
    size n, to a s number of standard deviations.
    
    AvDefProp: an average of the defective elements in the sample
    
    Sample size: integer
    
    Sigmas: the number of standard deviations for which the control
    limit wants to be calculated'''
    
    UCL = p + s*math.sqrt(p*(1-p)/n)
    LCL = p - s*math.sqrt(p*(1-p)/n)
    
    return UCL, LCL

# %%
def plot_pchart(ControlLimits)

# %%
data = pd.read_csv('continuous_factory_process.csv')
data.head()
# Out:
#             time_stamp  AmbientConditions.AmbientHumidity.U.Actual  \
# 0  2019-03-06 10:52:33                                       17.24
# 1  2019-03-06 10:52:34                                       17.24
# 2  2019-03-06 10:52:35                                       17.24
# 3  2019-03-06 10:52:36                                       17.24
# 4  2019-03-06 10:52:37                                       17.24
#
#    AmbientConditions.AmbientTemperature.U.Actual  \
# 0                                          23.53
# 1                                          23.53
# 2                                          23.53
# 3                                          23.53
# 4                                          23.53
#
#    Machine1.RawMaterial.Property1  Machine1.RawMaterial.Property2  \
# 0                           11.54                             200
# 1                           11.54                             200
# ...

# %%
data.shape
# Out:
# (14088, 116)

# %%
# list(data.columns)

plt.plot(data.iloc[:,4])
plt.show()

# %%
data.shape[1]
# Out:
# 116

# %%
pControlLimits(0.8,120)
# Out:
# (0.9095445115010332, 0.6904554884989669)
