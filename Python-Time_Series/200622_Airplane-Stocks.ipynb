# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Importing the dataset
df = pd.read_csv('Airplane_Crashes_and_Fatalities_Since_1908.csv')

# %%
df.head()
# Out:
#          Date   Time                            Location  \
# 0   9/17/1908  17:18                 Fort Myer, Virginia
# 1   7/12/1912   6:30             AtlantiCity, New Jersey
# 2    8/6/1913    NaN  Victoria, British Columbia, Canada
# 3    9/9/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# 2          NaN   NaN     1.0         1.0     0.0
# 3          NaN   NaN    20.0        14.0     0.0
# 4          NaN   NaN    30.0        30.0     0.0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  First U.S. dirigible Akron exploded just offsh...
# 2  The first fatal airplane accident in Canada oc...
# 3  The airship flew into a thunderstorm and encou...
# 4  Hydrogen gas which was being vented was sucked...

# %%
df.tail()
# Out:
#            Date  Time                                           Location  \
# 5263  5/20/2009  6:30                             Near Madiun, Indonesia
# 5264  5/26/2009   NaN                  Near Isiro, DemocratiRepubliCongo
# 5265   6/1/2009  0:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266   6/7/2009  8:30       Near Port Hope Simpson, Newfoundland, Canada
# 5267   6/8/2009   NaN                  State of Arunachal Pradesh, India
#
#                              Operator Flight #  \
# 5263  Military - Indonesian Air Force      NaN
# 5264                      Service Air      NaN
# 5265                       Air France      447
# 5266                       Strait Air      NaN
# 5267      Military - Indian Air Force      NaN
#
#                                           Route  \
# 5263                           Jakarta - Maduin
# 5264                               Goma - Isiro
# 5265                     Rio de Janeiro - Paris
# 5266  Lourdes de BlanSablon - Port Hope Simpson
# 5267                         Mechuka for Jorhat
#
#                                   Type Registration cn/In  Aboard  Fatalities  \
# 5263           Lockheed C-130 Hercules       A-1325  1982   112.0        98.0
# 5264                     Antonov An-26       9Q-CSA  5005     4.0         4.0
# 5265                   Airbus A330-203       F-GZCP   660   228.0       228.0
# 5266  Britten-Norman BN-2A-27 Islander      C-FJJR    424     1.0         1.0
# 5267                     Antonov An-32          NaN   NaN    13.0        13.0
#
#       Ground                                            Summary
# 5263     2.0  While on approach, the military transport cras...
# 5264     NaN  The cargo plane crashed while on approach to I...
# 5265     0.0  The Airbus went missing over the AtlantiOcean ...
# 5266     0.0  The air ambulance crashed into hills while att...
# 5267     0.0  The military transport went missing while en r...

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Location', 'Operator', 'Flight #', 'Route', 'Type',
#        'Registration', 'cn/In', 'Aboard', 'Fatalities', 'Ground', 'Summary'],
#       dtype='object')

# %%
plt.bar(df.Type.value_counts().index, height = df.Types.value_counts())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-67da5b07a48b> in <module>
# ----> 1 plt.bar(df.Type.value_counts().index, height = df.Types.value_counts())
#       2 plt.show()
#
# c:\users\dasep\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Types'

# %%
asDataFradf.Type.value_counts().index
# Out:
# Index(['Douglas DC-3', 'de Havilland Canada DHC-6 Twin Otter 300',
#        'Douglas C-47A', 'Douglas C-47', 'Douglas DC-4', 'Yakovlev YAK-40',
#        'Antonov AN-26', 'Junkers JU-52/3m', 'Douglas C-47B',
#        'De Havilland DH-4',
#        ...
#        'Douglas DC-8-43F', 'Antonov 24',
#        'de Hav Can. DHC-6 Tw Otter 100/ Cessna', 'Bell 206L-3',
#        'Gates Learjet 25D', 'Vickers Valetta Mk1 / Avero Lancaster',
#        'McDonnell Douglas DC-8F-54F', 'Short Stirling IV', 'V6 (airship)',
#        'Lockheed L-382B Hercules'],
#       dtype='object', length=2446)
